# %% [markdown]
# # pandas library

# %% [markdown]
# step-1 Importing the library

# %%
import pandas as pd

# %%
# importing data from clipboard
df = pd.read_clipboard()
df
# Out:
#        Name  Age  Weight
# 0  Muhammad   28      70
# 1       Ali   23      60
# 2     Ahamd   25      65
# 3    Zainab   27      68

# %% [markdown]
# ## importing data from excel file

# %%
import pandas as pd
df_excel = pd.read_excel('../04_libraries/dataframes/titanic_df.xlsx')
df_excel
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import pandas as pd
df_excel = pd.read_excel('../00_datasets/titanic_df.xlsx')
df_excel
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## csv and tsv files

# %%
# load csv data 
df_csv = pd.read_csv('../00_datasets/titanic.csv')
df_csv
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# load tsv data
df_tsv = pd.read_csv('../00_datasets/titanic.txt', sep='\t')
df_tsv
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Dummy dataset

# %%
# creat a dataframe from a dictionary for the people ages and names
data = {'Name': ['Muhammad','Ali','Ahamd','Zainab'],
        'Age': [28, 23, 25, 27],
        'Weight': [70, 60, 65, 68]}
data
df = pd.DataFrame(data)
df
# Out:
#        Name  Age  Weight
# 0  Muhammad   28      70
# 1       Ali   23      60
# 2     Ahamd   25      65
# 3    Zainab   27      68

# %%
df.to_clipboard()

# %%
df.to_excel('../00_datasets/people.xlsx', index=False)
df.to_csv('../00_datasets/people.csv', index=False)

# %% [markdown]
# # Advance Dataset Reading from Excel

# %%
string = "Aun\nAli\nAhmad\nAmmar"
print(string)
# Out:
# Aun
# Ali
# Ahmad
# Ammar

# %%
import pandas as pd
df = pd.read_excel(r'C:\Users\Hasnain Ali\Desktop\Pythan ka chilla\00_datasets\titanic_df.xlsx', sheet_name=0)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Reading Tabluar Data

# %%
import pandas as pd

df_tabulated = pd.read_table('../00_datasets/titanic.csv',sep ="\,",header=1)
                             
df_tabulated
# Out:
# C:\Users\Hasnain Ali\AppData\Local\Temp\ipykernel_12840\17363016.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df_tabulated = pd.read_table('../00_datasets/titanic.csv',sep ="\,",header=1)
#      0  3    male    22  1  0.1     7.25  S   Third    man   TRUE Unnamed: 11  \
# 0    1  1  female  38.0  1    0  71.2833  C   First  woman  False           C
# 1    1  3  female  26.0  0    0   7.9250  S   Third  woman  False         NaN
# 2    1  1  female  35.0  1    0  53.1000  S   First  woman  False           C
# 3    0  3    male  35.0  0    0   8.0500  S   Third    man   True         NaN
# 4    0  3    male   NaN  0    0   8.4583  Q   Third    man   True         NaN
# ..  .. ..     ...   ... ..  ...      ... ..     ...    ...    ...         ...
# ...
